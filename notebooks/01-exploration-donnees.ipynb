# %% [markdown]
# # 01 - Exploration des données
# Notebook de démarrage pour charger et visualiser des échantillons de données simulées.

# %%
# Imports de base
import pandas as pd
import plotly.express as px

# Exemple: df = pd.read_csv('../data/your_sample.csv')
print('Notebook prêt')
